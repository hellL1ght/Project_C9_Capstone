# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import micropip

# %% [markdown]
# Load the dataset into a dataframe.

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# %% [markdown]
# To obtain the dataset, utilize the download() function as defined above:

# %%
await download(file_path, "m2_survey_data.csv")
file_name="m2_survey_data.csv"

# %% [markdown]
# Utilize the Pandas method read_csv() to load the data into a dataframe.

# %%
df = pd.read_csv(file_name)

# %%
df.head(5)
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %% [markdown]
# > Note: This version of the lab is working on JupyterLite, which requires the dataset to be downloaded to the interface.While working on the downloaded version of this notebook on their local machines(Jupyter Anaconda), the learners can simply **skip the steps above,** and simply use the URL directly in the `pandas.read_csv()` function. You can uncomment and run the statements in the cell below.

# %%
#df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %%
df['ConvertedComp'].head(5)
df['ConvertedComp'].median()
# Out:
# 63016.0

# %%
df['ConvertedComp'].isnull().sum()
# Out:
# 0

# %%
df['ConvertedComp'][df['ConvertedComp'].isnull()] = df['ConvertedComp'].median()
# Out:
# <ipython-input-196-68f25b98692f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ConvertedComp'][df['ConvertedComp'].isnull()] = df['ConvertedComp'].median()

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
await micropip.install("scipy")

# %%
#testing
#bins = np.linspace(min(df["ConvertedComp"]), max(df["ConvertedComp"]), 20)
#bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
#group_names = ['BASIC', 'LOW' 'MID', 'HIGH', 'TOP']
#df['ConvertedComp_Binned'] = pd.cut(df['loan_int_rate'], bins, labels=group_names, include_lowest=True)

count, bin_edges = np.histogram(df['ConvertedComp'], bins=10, range=None)

ax = df['ConvertedComp'].plot(kind='hist', figsize=(8,6), bins = bin_edges, density = True, alpha = 0.7)
df['ConvertedComp'].plot(kind='kde', ax=ax, color='red', label='KDE')

plt.xlabel('Compensation in years')
plt.xticks(bin_edges, rotation=45)
plt.ylabel('Frequency')
plt.xlim(0,bin_edges[len(bin_edges)-1])

plt.title('Distribution of Compensation')
# Out:
# Text(0.5, 1.0, 'Distribution of Compensation')

# %%
# your code goes here
count, bin_edges = np.histogram(df['ConvertedComp'], bins=10, range=None)
df['ConvertedComp'].plot(kind='kde', color='red', label='KDE')
plt.xlabel('Compensation in years')
plt.xticks(bin_edges, rotation=45)
plt.ylabel('Frequency')
plt.xlim(0,bin_edges[len(bin_edges)-1])
# Out:
# (0.0, 2000000.0)

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
count, bin_edges = np.histogram(df['ConvertedComp'], bins=10, range=None)

ax = df['ConvertedComp'].plot(kind='hist', figsize=(8,6), bins = bin_edges, density = True, alpha = 0.7)
df['ConvertedComp'].plot(kind='kde', ax=ax, color='red', label='KDE')

plt.xlabel('Compensation in years')
plt.xticks(bin_edges, rotation=45)
plt.ylabel('Frequency')
plt.xlim(0,bin_edges[len(bin_edges)-1])

plt.title('Distribution of Compensation')
# Out:
# Text(0.5, 1.0, 'Distribution of Compensation')

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df['ConvertedComp'].median()
# Out:
# 63016.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
(df['Gender'] == 'Man').value_counts()
# Out:
# True     10480
# False      918
# Name: Gender, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
new_df['ConvertedComp'][df['Gender'] == 'Woman'].median()
# Out:
# 54996.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df['Age'].describe()
# Out:
# count    11398.000000
# mean        30.708923
# std          7.312971
# min         16.000000
# 25%         26.000000
# 50%         29.000000
# 75%         34.000000
# max         99.000000
# Name: Age, dtype: float64

# %%
df['Age'].median()
# Out:
# 29.0

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
df['Age'][df['Age'].isnull()] = df['Age'].median()
# Out:
# <ipython-input-205-354acb6d1840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][df['Age'].isnull()] = df['Age'].median()

# %%
# your code goes here
bin_edges = np.linspace(df['Age'].min(), df['Age'].max(), 10)
df['Age'].plot(kind='hist', bins = bin_edges, density=True, alpha=0.7)
plt.xlabel('Age of respondents')
plt.xticks(bin_edges)
plt.ylabel('Appearence in survey')
plt.title('Age to frequency')
plt.xlim(0,)
# Out:
# (0.0, 103.15)

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
df['ConvertedComp'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
q1 = np.percentile(df['ConvertedComp'], 25)
print(q1)
q3 = np.percentile(df['ConvertedComp'], 75)
print(q3)
iqr = q3 - q1
iqr
# Out:
# 29016.0
# 115464.0
# 86448.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
upper_bound = q3 + 1.5 * iqr
print(upper_bound)
lower_bound = q1 - 1.5 * iqr
print(lower_bound)
# Out:
# 245136.0
# -100656.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
outliers_mask = (df['ConvertedComp'] > upper_bound)
outliers_mask.sum()
# Out:
# 1627

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
new_df = df.drop(df['ConvertedComp'][outliers_mask].index, inplace=False)

# %%
bin_edges = np.linspace(new_df['ConvertedComp'].min(),new_df['ConvertedComp'].max(),10)
new_df['ConvertedComp'].plot(kind='hist', bins=bin_edges)
plt.xlabel('Compensation in years')
plt.xticks(bin_edges, rotation=45)
plt.ylabel('Frequency')
plt.xlim(0,bin_edges[len(bin_edges)-1])
# Out:
# (0.0, 241112.0)

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
numeric_columns = df.select_dtypes(include=['number'])
df[numeric_columns.columns.tolist()].corr()
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.013490      -0.003716    -0.015314    0.004621
# CompTotal       -0.013490   1.000000       0.001176     0.003510    0.007063
# ConvertedComp   -0.003716   0.001176       1.000000     0.013035    0.030193
# WorkWeekHrs     -0.015314   0.003510       0.013035     1.000000    0.026517
# CodeRevHrs       0.004621   0.007063       0.030193     0.026517    1.000000
# Age              0.004442   0.007307       0.023949     0.037121   -0.021921
#
#                     Age
# Respondent     0.004442
# CompTotal      0.007307
# ConvertedComp  0.023949
# WorkWeekHrs    0.037121
# CodeRevHrs    -0.021921
# Age            1.000000

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
